# %%
import numpy as np

# %%
x=np.array([[1,0,1,0],[1,0,1,1],[0,1,0,1]])
x
# Out:
# array([[1, 0, 1, 0],
#        [1, 0, 1, 1],
#        [0, 1, 0, 1]])

# %%
y=np.array([[1],[0],[1]])
y
# Out:
# array([[1],
#        [0],
#        [1]])

# %%
def sigmoid(x):
  return 1/(1+np.exp(-x))

# %%
def derivative_sigmoid(x):
  return x*(1-x)

# %%
epoch=5000
lr=0.1
input_neurons=x.shape[1]
hidden_neurons=3
output_neurons=1

# %%
wh=np.random.uniform(size=(input_neurons,hidden_neurons))
bh=np.random.uniform(size=(1,hidden_neurons))
wo=np.random.uniform(size=(hidden_neurons,output_neurons))
bo=np.random.uniform(size=(1,output_neurons))

# %%
for i in range(epoch):
  #forward
  hidden_input=np.dot(x,wh)
  hidden_input=hidden_input+bh
  hidden_activation=sigmoid(hidden_input)
  output_layer=np.dot(hidden_activation,wo)
  output=sigmoid(output_layer)
  #backward
  E=y-output
  slope_output=derivative_sigmoid(output)
  slope_hidden=derivative_sigmoid(hidden_activation)
  d_output=E*slope_output
  error_hidden=d_output.dot(wo.T)
  d_hidden=error_hidden*slope_hidden
  wo+=hidden_activation.T.dot(d_output)*lr
  bo+=np.sum(d_output,axis=0,keepdims=True)*lr
  wh+=x.T.dot(d_hidden)*lr
  bh+=np.sum(d_hidden,axis=0,keepdims=True)*lr

# %%
output
# Out:
# array([[0.95228127],
#        [0.07240675],
#        [0.95442057]])

# %%
import tensorflow as tf
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load Iris dataset
iris = load_iris()
X, y = iris.data, iris.target

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# One-hot encode labels
y_one_hot = tf.keras.utils.to_categorical(y, num_classes=3)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.2, random_state=42)

# Define the neural network architecture using Functional API
inputs = tf.keras.Input(shape=(4,))
hidden_layer = tf.keras.layers.Dense(16, activation='relu')(inputs)
hidden_layer = tf.keras.layers.Dropout(0.2)(hidden_layer)  # Adding Dropout for regularization
output_layer = tf.keras.layers.Dense(3, activation='softmax')(hidden_layer)

# Create the model
model = tf.keras.Model(inputs=inputs, outputs=output_layer)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}, Test Accuracy: {accuracy}')
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 83ms/step - loss: 1.0584 - accuracy: 0.3981 - val_loss: 1.0043 - val_accuracy: 0.4167
# Epoch 2/100
# 4/4 [==============================] - 0s 23ms/step - loss: 1.0868 - accuracy: 0.3796 - val_loss: 0.9823 - val_accuracy: 0.5000
# Epoch 3/100
# 4/4 [==============================] - 0s 22ms/step - loss: 1.0335 - accuracy: 0.4259 - val_loss: 0.9622 - val_accuracy: 0.5000
# Epoch 4/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.9708 - accuracy: 0.5093 - val_loss: 0.9428 - val_accuracy: 0.5000
# Epoch 5/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.9956 - accuracy: 0.5185 - val_loss: 0.9243 - val_accuracy: 0.5833
# Epoch 6/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.9652 - accuracy: 0.4815 - val_loss: 0.9059 - val_accuracy: 0.5833
# Epoch 7/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.9439 - accuracy: 0.5463 - val_loss: 0.8881 - val_accuracy: 0.5833
# Epoch 8/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8943 - accuracy: 0.5741 - val_loss: 0.8711 - val_accuracy: 0.6667
# Epoch 9/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.8698 - accuracy: 0.6574 - val_loss: 0.8550 - val_accuracy: 0.7500
# Epoch 10/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.8302 - accuracy: 0.6759 - val_loss: 0.8391 - val_accuracy: 0.7500
# Epoch 11/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8157 - accuracy: 0.6852 - val_loss: 0.8236 - val_accuracy: 0.7500
# Epoch 12/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8035 - accuracy: 0.6759 - val_loss: 0.8091 - val_accuracy: 0.7500
# Epoch 13/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.8313 - accuracy: 0.7130 - val_loss: 0.7947 - val_accuracy: 0.8333
# Epoch 14/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.7944 - accuracy: 0.7315 - val_loss: 0.7805 - val_accuracy: 0.9167
# Epoch 15/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.7603 - accuracy: 0.6852 - val_loss: 0.7663 - val_accuracy: 0.9167
# Epoch 16/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7393 - accuracy: 0.7685 - val_loss: 0.7527 - val_accuracy: 0.9167
# Epoch 17/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.7338 - accuracy: 0.7593 - val_loss: 0.7397 - val_accuracy: 0.9167
# Epoch 18/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7237 - accuracy: 0.6944 - val_loss: 0.7267 - val_accuracy: 0.9167
# Epoch 19/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.6724 - accuracy: 0.7685 - val_loss: 0.7144 - val_accuracy: 0.9167
# Epoch 20/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.6602 - accuracy: 0.7870 - val_loss: 0.7029 - val_accuracy: 0.9167
# Epoch 21/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6744 - accuracy: 0.7315 - val_loss: 0.6920 - val_accuracy: 0.9167
# Epoch 22/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6442 - accuracy: 0.7593 - val_loss: 0.6814 - val_accuracy: 0.9167
# Epoch 23/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.6212 - accuracy: 0.7593 - val_loss: 0.6712 - val_accuracy: 0.9167
# Epoch 24/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.6503 - accuracy: 0.7407 - val_loss: 0.6611 - val_accuracy: 0.9167
# Epoch 25/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6304 - accuracy: 0.7963 - val_loss: 0.6516 - val_accuracy: 0.9167
# Epoch 26/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.5928 - accuracy: 0.7963 - val_loss: 0.6426 - val_accuracy: 0.9167
# Epoch 27/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5647 - accuracy: 0.8241 - val_loss: 0.6336 - val_accuracy: 0.8333
# Epoch 28/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5823 - accuracy: 0.8056 - val_loss: 0.6246 - val_accuracy: 0.8333
# Epoch 29/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.5849 - accuracy: 0.8056 - val_loss: 0.6159 - val_accuracy: 0.8333
# Epoch 30/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5591 - accuracy: 0.7870 - val_loss: 0.6077 - val_accuracy: 0.8333
# Epoch 31/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5557 - accuracy: 0.8241 - val_loss: 0.5999 - val_accuracy: 0.8333
# Epoch 32/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5647 - accuracy: 0.8148 - val_loss: 0.5923 - val_accuracy: 0.8333
# Epoch 33/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5344 - accuracy: 0.8148 - val_loss: 0.5850 - val_accuracy: 0.8333
# Epoch 34/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5191 - accuracy: 0.8056 - val_loss: 0.5783 - val_accuracy: 0.8333
# Epoch 35/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5239 - accuracy: 0.8241 - val_loss: 0.5715 - val_accuracy: 0.8333
# Epoch 36/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5037 - accuracy: 0.8241 - val_loss: 0.5651 - val_accuracy: 0.8333
# Epoch 37/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4992 - accuracy: 0.8148 - val_loss: 0.5586 - val_accuracy: 0.8333
# Epoch 38/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5127 - accuracy: 0.8333 - val_loss: 0.5524 - val_accuracy: 0.8333
# Epoch 39/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4978 - accuracy: 0.8056 - val_loss: 0.5467 - val_accuracy: 0.8333
# Epoch 40/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4751 - accuracy: 0.8241 - val_loss: 0.5411 - val_accuracy: 0.8333
# Epoch 41/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4953 - accuracy: 0.8333 - val_loss: 0.5357 - val_accuracy: 0.8333
# Epoch 42/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5099 - accuracy: 0.7963 - val_loss: 0.5304 - val_accuracy: 0.8333
# Epoch 43/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4854 - accuracy: 0.8519 - val_loss: 0.5253 - val_accuracy: 0.8333
# Epoch 44/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4458 - accuracy: 0.8148 - val_loss: 0.5205 - val_accuracy: 0.9167
# Epoch 45/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4671 - accuracy: 0.8796 - val_loss: 0.5159 - val_accuracy: 0.9167
# Epoch 46/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4276 - accuracy: 0.8426 - val_loss: 0.5114 - val_accuracy: 0.9167
# Epoch 47/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4617 - accuracy: 0.8241 - val_loss: 0.5070 - val_accuracy: 0.9167
# Epoch 48/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4483 - accuracy: 0.8426 - val_loss: 0.5030 - val_accuracy: 0.9167
# Epoch 49/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4236 - accuracy: 0.8241 - val_loss: 0.4992 - val_accuracy: 0.9167
# Epoch 50/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4509 - accuracy: 0.8148 - val_loss: 0.4956 - val_accuracy: 0.9167
# Epoch 51/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4325 - accuracy: 0.8333 - val_loss: 0.4919 - val_accuracy: 0.9167
# Epoch 52/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4693 - accuracy: 0.8056 - val_loss: 0.4879 - val_accuracy: 0.9167
# Epoch 53/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4333 - accuracy: 0.7870 - val_loss: 0.4844 - val_accuracy: 0.9167
# Epoch 54/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4125 - accuracy: 0.8519 - val_loss: 0.4811 - val_accuracy: 0.9167
# Epoch 55/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4215 - accuracy: 0.8611 - val_loss: 0.4775 - val_accuracy: 0.9167
# Epoch 56/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4096 - accuracy: 0.8241 - val_loss: 0.4741 - val_accuracy: 0.9167
# Epoch 57/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3949 - accuracy: 0.8426 - val_loss: 0.4709 - val_accuracy: 0.9167
# Epoch 58/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4071 - accuracy: 0.8148 - val_loss: 0.4674 - val_accuracy: 0.9167
# Epoch 59/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4048 - accuracy: 0.8519 - val_loss: 0.4639 - val_accuracy: 0.9167
# Epoch 60/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3994 - accuracy: 0.8519 - val_loss: 0.4601 - val_accuracy: 0.9167
# Epoch 61/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3777 - accuracy: 0.8333 - val_loss: 0.4568 - val_accuracy: 0.9167
# Epoch 62/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3827 - accuracy: 0.8796 - val_loss: 0.4539 - val_accuracy: 0.9167
# Epoch 63/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3942 - accuracy: 0.8426 - val_loss: 0.4512 - val_accuracy: 0.9167
# Epoch 64/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4216 - accuracy: 0.8519 - val_loss: 0.4487 - val_accuracy: 0.9167
# Epoch 65/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3870 - accuracy: 0.8519 - val_loss: 0.4458 - val_accuracy: 0.9167
# Epoch 66/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3923 - accuracy: 0.8426 - val_loss: 0.4431 - val_accuracy: 0.9167
# Epoch 67/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3568 - accuracy: 0.8611 - val_loss: 0.4409 - val_accuracy: 0.9167
# Epoch 68/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3656 - accuracy: 0.8889 - val_loss: 0.4385 - val_accuracy: 0.9167
# Epoch 69/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3961 - accuracy: 0.8333 - val_loss: 0.4363 - val_accuracy: 0.9167
# Epoch 70/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3617 - accuracy: 0.8796 - val_loss: 0.4338 - val_accuracy: 0.9167
# Epoch 71/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3613 - accuracy: 0.8519 - val_loss: 0.4315 - val_accuracy: 0.9167
# Epoch 72/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3634 - accuracy: 0.8426 - val_loss: 0.4293 - val_accuracy: 0.9167
# Epoch 73/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3572 - accuracy: 0.8519 - val_loss: 0.4266 - val_accuracy: 0.9167
# Epoch 74/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3562 - accuracy: 0.8704 - val_loss: 0.4242 - val_accuracy: 0.9167
# Epoch 75/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3403 - accuracy: 0.8704 - val_loss: 0.4212 - val_accuracy: 0.9167
# Epoch 76/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3776 - accuracy: 0.8241 - val_loss: 0.4184 - val_accuracy: 0.9167
# Epoch 77/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3354 - accuracy: 0.8981 - val_loss: 0.4156 - val_accuracy: 0.9167
# Epoch 78/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3394 - accuracy: 0.8889 - val_loss: 0.4123 - val_accuracy: 0.9167
# Epoch 79/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3612 - accuracy: 0.8796 - val_loss: 0.4093 - val_accuracy: 0.9167
# Epoch 80/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3446 - accuracy: 0.8519 - val_loss: 0.4061 - val_accuracy: 0.9167
# Epoch 81/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3221 - accuracy: 0.8611 - val_loss: 0.4033 - val_accuracy: 0.9167
# Epoch 82/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3453 - accuracy: 0.8611 - val_loss: 0.4006 - val_accuracy: 0.9167
# Epoch 83/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3356 - accuracy: 0.8519 - val_loss: 0.3977 - val_accuracy: 0.9167
# Epoch 84/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3231 - accuracy: 0.8889 - val_loss: 0.3952 - val_accuracy: 0.9167
# Epoch 85/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3218 - accuracy: 0.8704 - val_loss: 0.3931 - val_accuracy: 0.9167
# Epoch 86/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3657 - accuracy: 0.8241 - val_loss: 0.3904 - val_accuracy: 0.9167
# Epoch 87/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3279 - accuracy: 0.8704 - val_loss: 0.3881 - val_accuracy: 0.9167
# Epoch 88/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3309 - accuracy: 0.8704 - val_loss: 0.3858 - val_accuracy: 0.9167
# Epoch 89/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3241 - accuracy: 0.8796 - val_loss: 0.3845 - val_accuracy: 0.9167
# Epoch 90/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3189 - accuracy: 0.8611 - val_loss: 0.3833 - val_accuracy: 0.9167
# Epoch 91/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3125 - accuracy: 0.8981 - val_loss: 0.3819 - val_accuracy: 0.9167
# Epoch 92/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3146 - accuracy: 0.8611 - val_loss: 0.3802 - val_accuracy: 0.9167
# Epoch 93/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3283 - accuracy: 0.8889 - val_loss: 0.3788 - val_accuracy: 0.9167
# Epoch 94/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3366 - accuracy: 0.8889 - val_loss: 0.3781 - val_accuracy: 0.9167
# Epoch 95/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3097 - accuracy: 0.8981 - val_loss: 0.3767 - val_accuracy: 0.9167
# Epoch 96/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3201 - accuracy: 0.8796 - val_loss: 0.3756 - val_accuracy: 0.9167
# Epoch 97/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3002 - accuracy: 0.8981 - val_loss: 0.3741 - val_accuracy: 0.9167
# Epoch 98/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2850 - accuracy: 0.8981 - val_loss: 0.3723 - val_accuracy: 0.9167
# Epoch 99/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3247 - accuracy: 0.8704 - val_loss: 0.3702 - val_accuracy: 0.9167
# Epoch 100/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3002 - accuracy: 0.8889 - val_loss: 0.3683 - val_accuracy: 0.9167
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2396 - accuracy: 0.9667
# Test Loss: 0.23962458968162537, Test Accuracy: 0.9666666388511658

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.15.0

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])

# %%
predictions=model(x_train[:1]).numpy()
predictions
# Out:
# array([[0.51774454, 0.09231597, 0.45476723, 0.76539063, 0.5212706 ,
#         0.32809237, 0.5137121 , 0.133837  , 0.09987022, 0.12963833]],
#       dtype=float32)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
tf.nn.softmax(predictions).numpy()
# Out:
# array([[0.11470264, 0.07495698, 0.10770173, 0.14693482, 0.1151078 ,
#         0.09488739, 0.11424104, 0.07813479, 0.07552537, 0.07780742]],
#       dtype=float32)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
loss_fn(y_train[:1], predictions).numpy()
# Out:
# 2.3550644

# %%
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2983 - accuracy: 0.9127
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1466 - accuracy: 0.9559
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1093 - accuracy: 0.9664
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0916 - accuracy: 0.9718
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0782 - accuracy: 0.9750

# %%
model.evaluate(x_test,  y_test, verbose=2)

# %%
probability_model = tf.keras.Sequential([
  model,
  tf.keras.layers.Softmax()
])

# %%
probability_model(x_test[:5])
